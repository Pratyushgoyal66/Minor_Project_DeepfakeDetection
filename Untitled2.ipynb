# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyushgoyal66/Minor_Project_DeepfakeDetection/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create directory in which we will do our work
# !mkdir deepFake_detection_algo

# %%
#Copy dataset from myDrive
# !cp /content/drive/MyDrive/Minor_project/deepfake_database.zip /content/deepFake_detection_algo

# %%
cd deepFake_detection_algo
# Out:
# /content/deepFake_detection_algo

# %%
#Unzip Dataset
!7z x deepfake_database.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 192901191 bytes (184 MiB)
#
# Extracting archive: deepfake_database.zip
# --
# Path = deepfake_database.zip
# Type = zip
# Physical Size = 192901191
#
# Everything is Ok
#
# Folders: 8
# Files: 19464
# Size:       191651221
# Compressed: 192901191

# %%
#Rename df to fake before running this cell
# !mv /content/deepFake_detection_algo/deepfake_database/deepfake_database/validation/fake/* /content/deepFake_detection_algo/deepfake_database/deepfake_database/train:test/fake
# !mv /content/deepFake_detection_algo/deepfake_database/deepfake_database/validation/real/* /content/deepFake_detection_algo/deepfake_database/deepfake_database/train:test/real

# %%
cd /content/deepFake_detection_algo
# Out:
# /content/deepFake_detection_algo

# %%
#Create following directories to run the coming data_sorting script easily. Otherwise edit the data_sorting script as required.
# !mkdir deepfakedetection
# !mv /content/deepFake_detection_algo/deepfake_database/deepfake_database/train:test/* /content/deepFake_detection_algo/deepfakedetection 
# !mkdir images
# !mkdir splits

# %%
#Add empty folder to ignore
# !mkdir ignore
# !mv /content/deepFake_detection_algo/deepfake_database /content/deepFake_detection_algo/ignore

# %%
#data_sorting script
import cv2, csv, os, shutil
import numpy as np
path = os.getcwd()
dataset_deepfakedetection = path + '/deepfakedetection'
datasets = [dataset_deepfakedetection]
output_folder = path + '/images/'
with open(output_folder + 'images.csv', 'a') as csv_file:
  filewriter = csv.writer(csv_file, delimiter=',')
  filewriter.writerow(['image_id','fake','original_dataset'])
for dataset in datasets:
  for real_image in os.listdir(dataset + '/real'):
    if real_image.endswith('.jpg'):
      shutil.move(dataset + '/real/' + real_image, output_folder + real_image)
      with open(output_folder + 'images.csv', 'a') as csv_file:
        filewriter = csv.writer(csv_file, delimiter=',')
        filewriter.writerow([real_image, 0, dataset.rsplit('/', 1)[1]])
    else:
      continue
  for fake_image in os.listdir(dataset + '/fake'):
    if fake_image.endswith('.jpg'):
      shutil.move(dataset + '/fake/' + fake_image, output_folder + fake_image)
      with open(output_folder + 'images.csv', 'a') as csv_file:
        filewriter = csv.writer(csv_file, delimiter=',')
        filewriter.writerow([fake_image, 1, dataset.rsplit('/', 1)[1]])
    else:
      continue

print("Files have been successfully moved into the output folder and all information put into a CSV file.")
# Out:
# Files have been successfully moved into the output folder and all information put into a CSV file.

# %%
#No need to run if you already have the train, test, val split csv files. You can just copy them to myDrive to Splits folder.
import pandas as pd 
df=pd.read_csv('images/images.csv')
df = df.sample(frac=1)
#Shuffle dataframe
df_1 = df.iloc[:15564,:] 
df_2 = df.iloc[15564:17510,:] 
df_3 = df.iloc[17510:,:]
#Write train test val files
df_1.to_csv('splits/train_split.csv', index=False) 
df_2.to_csv('splits/val_split.csv', index=False) 
df_3.to_csv('splits/test_split.csv', index=False) 
#Copy to myDrive for future use
# !cp /content/deepFake_detection_algo/splits/* /content/drive/MyDrive/Minor_project/Splits

# %%
#Create numpy array of each image
import pandas as  pd
import numpy as np
import cv2

def makeDataSet(file_csv):

  x = []
  y = []

  for i in file_csv.index:

    if(file_csv['image_id'][i]=="image_id"):
      continue;
  
    img_address = "images/" + str(file_csv['image_id'][i]);

    img = cv2.imread(img_address)
    img = cv2.resize(img,(256,256))

    img_array = np.array(img)

    x.append(img_array)
    y.append(file_csv['fake'][i])  
  
  x = np.array(x)
  y = np.array(y)

  return x,y

# %%
#Create datasets
x_train,y_train = makeDataSet(pd.read_csv('/content/deepFake_detection_algo/splits/train_split.csv'))
x_validate,y_validate = makeDataSet(pd.read_csv('/content/deepFake_detection_algo/splits/val_split.csv'))
x_test,y_test = makeDataSet(pd.read_csv('/content/deepFake_detection_algo/splits/test_split.csv'))

# %%
#Test for shape
print(x_train.shape)
print(y_train.shape)
print(x_validate.shape)
print(y_validate.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (15564, 256, 256, 3)
# (15564,)
# (1946, 256, 256, 3)
# (1946,)
# (1946, 256, 256, 3)
# (1946,)

# %%
#Imports Required 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras import backend as K                #To Clear GPU Allocated Memory
import tensorflow as tf
import numpy as np

# %%
K.clear_session()                             #To Clear GPU Allocated Memory
tf.compat.v1.GPUOptions(allow_growth=True)    #Allow Memory to grow instead of all allocated at start
# Out:
# allow_growth: true

# %%
model= Sequential()

# %%
cnn1= Conv2D(filters=16, kernel_size=(5,5), strides=(1,1), padding= "SAME",activation="relu", use_bias=True, input_shape=(256,256,3))
model.add(cnn1)
model.add(MaxPool2D(pool_size=(2,2), strides=(1,1)))
model.add(Conv2D(filters=32, kernel_size=(5,5), strides=(1,1), padding= "SAME",activation="relu", use_bias=True))
model.add(MaxPool2D(pool_size=(2,2), strides=(1,1)))
model.add(Conv2D(filters=64, kernel_size=(5,5), strides=(1,1), padding= "SAME",activation="relu", use_bias=True))
model.add(MaxPool2D(pool_size=(2,2), strides=(1,1)))
model.add(Conv2D(filters=128, kernel_size=(5,5), strides=(1,1), padding= "SAME",activation="relu", use_bias=True))
model.add(MaxPool2D(pool_size=(2,2), strides=(1,1)))
model.add(Flatten())
model.add(Dense(units=1,activation="sigmoid"))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'], experimental_steps_per_execution = 2)

# %%
#Generate summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 16)      1216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 255, 255, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 255, 255, 32)      12832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 254, 254, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 254, 254, 64)      51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 253, 253, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 253, 253, 128)     204928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 252, 252, 128)     0
# _________________________________________________________________
# flatten (Flatten)            (None, 8128512)           0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 8128513
# =================================================================
# Total params: 8,398,753
# Trainable params: 8,398,753
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train, epochs=10, validation_data=(x_validate,y_validate))
# Out:
# Epoch 1/10
# 487/487 [==============================] - 270s 554ms/step - loss: 0.7957 - accuracy: 0.5907 - val_loss: 0.6774 - val_accuracy: 0.5961
# Epoch 2/10
# 487/487 [==============================] - 268s 550ms/step - loss: 0.7403 - accuracy: 0.5897 - val_loss: 0.6750 - val_accuracy: 0.5961
# Epoch 3/10
# 487/487 [==============================] - 268s 549ms/step - loss: 0.6787 - accuracy: 0.5898 - val_loss: 0.6745 - val_accuracy: 0.5961
# Epoch 4/10
# 487/487 [==============================] - 268s 550ms/step - loss: 0.6762 - accuracy: 0.5898 - val_loss: 0.6744 - val_accuracy: 0.5961
# Epoch 5/10
# 487/487 [==============================] - 268s 549ms/step - loss: 0.6785 - accuracy: 0.5897 - val_loss: 0.6744 - val_accuracy: 0.5961
# Epoch 6/10
# 487/487 [==============================] - 267s 549ms/step - loss: 0.6841 - accuracy: 0.5897 - val_loss: 0.6748 - val_accuracy: 0.5961
# Epoch 7/10
# 487/487 [==============================] - 268s 549ms/step - loss: 0.6768 - accuracy: 0.5903 - val_loss: 0.6748 - val_accuracy: 0.5956
# Epoch 8/10
# 487/487 [==============================] - 267s 549ms/step - loss: 0.6762 - accuracy: 0.5898 - val_loss: 0.6746 - val_accuracy: 0.5961
# Epoch 9/10
# 487/487 [==============================] - 267s 549ms/step - loss: 0.6761 - accuracy: 0.5897 - val_loss: 0.6745 - val_accuracy: 0.5961
# Epoch 10/10
# 487/487 [==============================] - 267s 549ms/step - loss: 0.6760 - accuracy: 0.5902 - val_loss: 0.6744 - val_accuracy: 0.5961

# %%
#TO Load a previously saved model, uncomment the following code
model = tf.keras.models.load_model("DeepFake_Detection")

# %%
evaluated= model.evaluate(x_test,y_test)
# Out:
# 61/61 [==============================] - 10s 159ms/step - loss: 0.1343 - accuracy: 0.9460

# %%
print('Test loss:', evaluated[0])
print('Test accuracy:', evaluated[1]*100,"%")

# %%
#Save trained Model
# !cp -r /content/drive/MyDrive/DeepFake_Detection /content/deepFake_detection_algo
#model.save("DeepFake_Detection")

# %%
#Transfer model to myDrive for future Use
# !cp -r /content/deepFake_detection_algo/DeepFake_Detection /content/drive/MyDrive/minor_project

# %%
# !cp /content/drive/MyDrive/Celeb-DF-v2.zip /content/deepFake_detection_algo

# %%
!7z x Celeb-DF-v2.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 9952957051 bytes (9492 MiB)
#
# Extracting archive: Celeb-DF-v2.zip
# --
# Path = Celeb-DF-v2.zip
# Type = zip
# Physical Size = 9952957051
# 64-bit = +
#
# Everything is Ok
#
# Folders: 3
# Files: 6530
# Size:       10156100196
# Compressed: 9952957051

# %%
import sys, os, csv, cv2, dlib
import pandas as pd

# Version of getFrame() function that crops facial area
face_detector = dlib.get_frontal_face_detector()
image_folder = "Image_Celeb/"
def getFrame(vid, sec, path, filename, count):
  vid.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
  hasFrames, image = vid.read()
  if hasFrames:
    faces = face_detector(image, 1)
    print("Number of faces detected: {}".format(len(faces)))
    for i, d in enumerate(faces):
        cropped_face = image[d.top():d.bottom(), d.left():d.right()]
        cv2.imwrite(image_folder + filename + "_frame"+str(count)+".jpg", cropped_face)
    return hasFrames

# Version of getFrame() function that keeps full video frame
"""
def getFrame(vid, sec, path, filename, count):
  vid.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
  hasFrames, image = vid.read()
  if hasFrames:
    cv2.imwrite(image_folder + filename + "_frame"+str(count)+".jpg", image)
    return hasFrames
"""

video_folder = "Celeb-real/"
video = "id0_0000.mp4"
frameRate = 0.5 
count = 1
sec = 0
print("Separating video {} into frames.".format(video))
vidcap = cv2.VideoCapture("Celeb-real/id0_0000.mp4")
success = getFrame(vidcap, sec, video_folder, video, count)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(vidcap, sec, video_folder, video, count)
# Out:
# Separating video id0_0000.mp4 into frames.
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1
# Number of faces detected: 1

# %%
x = []
y = []
img_address = "Image_Celeb/id0_0000.mp4_frame26.jpg"
img = cv2.imread(img_address)
img = cv2.resize(img,(256,256))
img_array = np.array(img)
x.append(img_array)
y.append(1)  
x = np.array(x)
y = np.array(y)
evaluated= model.evaluate(x,y)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3249 - accuracy: 1.0000

# %%
#data_sorting script
import cv2, csv, os, shutil
import numpy as np
path = os.getcwd()
dataset_deepfakedetection = path + '/Image_Celeb'
datasets = [dataset_deepfakedetection]
output_folder = path + '/images/'
with open(output_folder + 'images.csv', 'a') as csv_file:
  filewriter = csv.writer(csv_file, delimiter=',')
  filewriter.writerow(['image_id','fake','original_dataset'])
for dataset in datasets:
  for real_image in os.listdir(dataset + '/real'):
    if real_image.endswith('.jpg'):
      shutil.move(dataset + '/real/' + real_image, output_folder + real_image)
      with open(output_folder + 'images.csv', 'a') as csv_file:
        filewriter = csv.writer(csv_file, delimiter=',')
        filewriter.writerow([real_image, 0, dataset.rsplit('/', 1)[1]])
    else:
      continue
  for fake_image in os.listdir(dataset + '/fake'):
    if fake_image.endswith('.jpg'):
      shutil.move(dataset + '/fake/' + fake_image, output_folder + fake_image)
      with open(output_folder + 'images.csv', 'a') as csv_file:
        filewriter = csv.writer(csv_file, delimiter=',')
        filewriter.writerow([fake_image, 1, dataset.rsplit('/', 1)[1]])
    else:
      continue

print("Files have been successfully moved into the output folder and all information put into a CSV file.")

# %%
# %matplotlib inline
import glob
import matplotlib
from keras import models
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

import imageio as im

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %%
img_path = 'images/100_160.jpg'
img = image.load_img(img_path, target_size=(256, 256))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.
plt.imshow(img_tensor[0])
plt.show()
print(img_tensor.shape)
# Out:
# (1, 256, 256, 3)

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
images = np.vstack([x])
classes = model.predict_classes(images, batch_size=10)
print("Predicted class is:",classes)
# Out:
# WARNING:tensorflow:From <ipython-input-65-23a0763e2e24>:4: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Predicted class is: [[0]]

# %%
layer_outputs = [layer.output for layer in model.layers[:12]] 
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)

# %%
first_layer_activation = activations[0]
print(first_layer_activation.shape)
# Out:
# (1, 256, 256, 16)

# %%
plt.matshow(first_layer_activation[0, :, :, 4], cmap='viridis')

# %%
layer_names = []
for layer in model.layers[:12]:
    layer_names.append(layer.name) # Names of the layers, so you can have them as part of your plot
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations): # Displays the feature maps
    n_features = layer_activation.shape[-1] # Number of features in the feature map
    size = layer_activation.shape[1] #The feature map has shape (1, size, size, n_features).
    n_cols = n_features // images_per_row # Tiles the activation channels in this matrix
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    for col in range(n_cols): # Tiles each filter into a big horizontal grid
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            channel_image -= channel_image.mean() # Post-processes the feature to make it visually palatable
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, # Displays the grid
                         row * size : (row + 1) * size] = channel_image
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-1e86b68282ff> in <module>()
#       7     size = layer_activation.shape[1] #The feature map has shape (1, size, size, n_features).
#       8     n_cols = n_features // images_per_row # Tiles the activation channels in this matrix
# ----> 9     display_grid = np.zeros((size * n_cols, images_per_row * size))
#      10     for col in range(n_cols): # Tiles each filter into a big horizontal grid
#      11         for row in range(images_per_row):
#
# ValueError: array is too big; `arr.size * arr.dtype.itemsize` is larger than the maximum possible size.
